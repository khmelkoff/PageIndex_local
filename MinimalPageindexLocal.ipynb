# %%
import os
os.environ["OPENAI_API_KEY"] = 'DUMMY'
os.environ["OLLAMA_HOST"] = 'http://192.168.1.43:11434/v1' # or http://localhost:11434/v1
os.environ["OLLAMA_TIMEOUT"] = '1200'
os.environ["ACCURACY_THRESHOLD"] = '0.3'

# %%
import json
import pickle
from pageindex import *
# from pageindex.page_index_md import md_to_tree
from pageindex.utils import ConfigLoader, llm_acompletion, create_node_mapping
from pprint import pprint

# %%
import nest_asyncio
nest_asyncio.apply()
import asyncio

# %% [markdown]
# ### Config

# %%
user_opt = {
    'model':"openai/gpt-oss:20b", # gpt-oss:20b",
    'retrieve_model':"openai/gpt-oss:20b",
    'toc_check_page_num':20,
    'max_page_num_each_node':10,
    'max_token_num_each_node':10000,
    'if_add_node_id':"yes",
    'if_add_node_summary':"yes",
    'if_add_doc_description':"no",
    'if_add_node_text':"yes",
}

opt = ConfigLoader().load({k: v for k, v in user_opt.items() if v is not None})

# %% [markdown]
# ## Step 1: PageIndex Tree Generation

# %%
# %%time
pdf_path = './data\\2077.pdf'
def start():
    toc_with_page_number = page_index_main(pdf_path, opt)
    print('Processing complete')
    return toc_with_page_number

result = start()
# Out:
# Parsing PDF...
# start find_toc_pages
# response {
#     "thinking": "The provided text contains headings such as \"Highlights\", \"Abstract\", \"Keywords\", and a single numbered section \"1. Introduction\", but it does not include a separate list that enumerates sections, subsections, or page numbers typical of a table of contents. Therefore, there is no table of contents present.",
#     "toc_detected": "no"
# }
#
# response {
#     "thinking": "The provided text consists of continuous prose discussing the paper's motivation, context, and contributions. It does not contain a structured list of sections, chapters, or headings that would constitute a table of contents. Therefore, no table of contents is present.",
#     "toc_detected": "no"
# }
#
# response {
#     "thinking": "The provided text contains only a few section headings (e.g., \"2. Literature review\" and \"2.1. Intersection of science fiction and technological foresight\") that appear to be part of the main body of the document rather than a separate, comprehensive list of sections and subsections that would constitute a table of contents. A true table of contents would enumerate all major sections, chapters, or parts of the document, usually at the beginning, and this excerpt does not provide such a list. Therefore, there is no table of contents present in the given text.",
#     "toc_detected": "no"
# }
#
# response {
#     "thinking": "The provided text contains a single section heading (\"2.2. Science fiction and technological advancements\") but does not include a list of sections, chapters, or any structured outline that would constitute a table of contents. There is no \"Table of Contents\" heading or enumerated list of topics. Therefore, a table of contents is not present.",
#     "toc_detected": "no"
# }
#
# response {
#     "thinking": "The provided text contains individual section headings (e.g., \"2.3. Video games as a medium for future technologies\" and \"2.4. The unique contributions and predictive potential of Cyberpunk 2077\"), but it does not include a separate, enumerated list of sections and subsections that would constitute a table of contents. Therefore, there is no table of contents present.",
#     "toc_detected": "no"
# }
#
# response {
#     "thinking": "The provided text contains a single section heading \"2.5. Technologies in Cyberpunk 2077\" but does not include a list of sections, chapters, or any structured outline that would constitute a table of contents. Therefore, there is no table of contents present.",
#     "toc_detected": "no"
# }
#
# response {
#     "thinking": "The provided text contains section headings such as \"3. Methodology\" and \"3.1. Data collection\", but it does not include a list of sections with numbers and titles that would constitute a table of contents. Therefore, no table of contents is present.",
#     "toc_detected": "no"
# }
#
# response {
#     "thinking": "The provided text contains section headings and a reference to Table 1, but it does not include a list of sections, chapters, or any structured outline that would constitute a table of contents. Therefore, there is no table of contents present.",
#     "toc_detected": "no"
# }
#
# response {
#     "thinking": "The provided text contains section headings such as \"4.1. Overarching themes\" and \"4.2. Human augmentation and cybernetic enhancements\", but it does not include a separate, enumerated list of sections or chapters that would constitute a table of contents. Therefore, there is no table of contents present.",
#     "toc_detected": "no"
# }
#
# response {
#     "thinking": "The provided text contains narrative paragraphs and section headings such as \"Cybernetic Prosthetics\" and \"Artificial Biological Augmentations\", but it does not include a separate list of sections, chapters, or topics that would constitute a table of contents. Therefore, there is no table of contents present.",
#     "toc_detected": "no"
# }
#
# response {
#     "thinking": "The provided text contains a single section heading (4.3. Brain–computer interfaces and simulated reality) embedded within the body of the document. It does not present a separate, enumerated list of sections, chapters, or topics that would constitute a table of contents. Therefore, there is no table of contents in the given text.",
#     "toc_detected": "no"
# }
#
# response {
#     "thinking": "The provided text contains a single section heading (4.4. Digital representation and information access) and descriptive paragraphs, but it does not present a list of sections, chapters, or any structured outline that would constitute a table of contents. Therefore, there is no table of contents in the given text.",
#     "toc_detected": "no"
# }
#
# response {
#     "thinking": "The provided text contains section headings such as \"Advanced Biometric Authentication\" and \"Information Transfer and Security\", but it does not include a separate list that enumerates sections, chapters, or topics with page numbers or a structured outline typical of a table of contents. Therefore, there is no table of contents present in the text.",
#     "toc_detected": "no"
# }
#
# response {
#     "thinking": "The provided text contains a single subsection heading \"4.6. Autonomous vehicles and transportation\" but does not include a structured list of sections, chapters, or a numbered outline that would constitute a table of contents. Therefore, there is no table of contents present.",
#     "toc_detected": "no"
# }
#
# response {
#     "thinking": "The provided text contains section headings and figure references, but it does not include a structured list of sections, chapters, or any enumerated table of contents. Therefore, there is no table of contents present.",
#     "toc_detected": "no"
# }
#
# response {
#     "thinking": "The provided text contains narrative content, references to a table (Table 1), and a section heading (5. Discussion), but it does not include a structured list of sections, chapters, or any other typical table of contents format. Therefore, there is no table of contents present.",
#     "toc_detected": "no"
# }
#
# response {
#     "thinking": "The provided text consists of continuous prose without any headings, numbered or bulleted lists, or a structured outline that would indicate a table of contents. It does not contain sections such as \"1. Introduction\", \"2. Methods\", or a list of chapters or topics. Therefore, there is no table of contents present.",
#     "toc_detected": "no"
# }
#
# response {
#     "thinking": "The provided text contains a reference to a specific table (Table 1) but does not include a list of sections, chapters, or any structured outline that would constitute a table of contents. There is no heading list or navigational structure present.",
#     "toc_detected": "no"
# }
#
# response {
#     "thinking": "The provided text contains a section heading \"6. Conclusion\" and a reference to \"Table 1\", but it does not include a list of sections, chapters, or page numbers that would constitute a table of contents. There is no heading titled \"Table of Contents\" or any structured list that enumerates the document's sections. Therefore, the text does not contain a table of contents.",
#     "toc_detected": "no"
# }
#
# no toc found
# process_no_toc
# start_index: 1
# start generate_toc_init
# Document validation: 19 pages, max allowed index: 19
# start verify_toc
# check all items
# accuracy: 36.36%
# start fix_incorrect_toc
# Fixing 14 incorrect results
# start fix_incorrect_toc with 14 incorrect results
# Fixing 1 incorrect results
# start fix_incorrect_toc with 1 incorrect results
# Fixing 1 incorrect results
# start fix_incorrect_toc with 1 incorrect results
# Processing complete
# CPU times: total: 2.45 s
# Wall time: 29min 37s

# %%
# pprint(result['structure'][0]) # print first node

# %% [markdown]
# #### Save or restore TOC with page number

# %%
with open("data/2077_result_w_text_last.pkl", 'wb') as f:
    pickle.dump(result, f)

# %%
# with open("data/2077_result_w_text_last.pkl", 'rb') as f:
#     result = pickle.load(f)

# %% [markdown]
# #### 1.2 Get the generated PageIndex tree structure

# %%
utils.list_to_tree(result['structure'])
# Out:
# [{'title': 'Introduction', 'start_index': 1, 'end_index': 3},
#  {'title': 'Literature review', 'start_index': 3, 'end_index': 3},
#  {'title': 'Methodology', 'start_index': 7, 'end_index': 7},
#  {'title': 'Themes and technologies', 'start_index': 8, 'end_index': 9},
#  {'title': 'Discussion', 'start_index': 19, 'end_index': 19},
#  {'title': 'Conclusion', 'start_index': 19, 'end_index': 19},
#  {'title': 'CRediT authorship contribution statement',
#   'start_index': 19,
#   'end_index': 19},
#  {'title': 'Declaration of Generative AI and AI-assisted technologies in the writing process',
#   'start_index': 19,
#   'end_index': 19}]

# %%
# Remove document text chunks from Tree
tree_with_text = result['structure'].copy()
tree_without_text = utils.remove_fields(tree_with_text, fields=['text'])
# pprint(json.dumps(tree_without_text, indent=2))

# %%
# check JSON
utils.print_json(result, max_len=50, indent=2)
# Out:
# {
#   "doc_name": "2077.pdf",
#   "structure": [
#     {
#       "title": "Introduction",
#       "node_id": "0000",
#       "start_index": 1,
#       "end_index": 3,
#       "summary": "The paper examines how the video game Cyberpunk 20...",
#       "text": "A Cyberpunk 2077 perspective on the prediction and..."
#     },
#     {
#       "title": "Literature review",
#       "node_id": "0001",
#       "start_index": 3,
#       "end_index": 3,
#       "summary": "The partial document examines how *Cyberpunk 2077*...",
#       "text": "contextualizing Cyberpunk 2077 within the broader ...",
#       "nodes": [
#         {
#           "title": "Intersection of science fiction and technological ...",
#           "node_id": "0002",
#           "start_index": 3,
#           "end_index": 4,
#           "summary": "The partial document surveys how science‑fiction n...",
#           "text": "contextualizing Cyberpunk 2077 within the broader ..."
#         },
#         {
#           "title": "Science fiction and technological advancements",
#           "node_id": "0003",
#           "start_index": 4,
#           "end_index": 5,
#           "summary": "The partial document reviews how decolonial theory...",
#           "text": "Incorporating decolonial perspectives into foresig..."
#         },
#         {
#           "title": "Video games as a medium for future technologies",
#           "node_id": "0004",
#           "start_index": 5,
#           "end_index": 5,
#           "summary": "The partial document explores how science‑fiction ...",
#           "text": "the authentication of information [45], [46]. Furt..."
#         },
#         {
#           "title": "The unique contributions and predictive potential ...",
#           "node_id": "0005",
#           "start_index": 5,
#           "end_index": 7,
#           "summary": "The partial document surveys how science‑fiction m...",
#           "text": "the authentication of information [45], [46]. Furt..."
#         }
#       ]
#     },
#     {
#       "title": "Methodology",
#       "node_id": "0006",
#       "start_index": 7,
#       "end_index": 7,
#       "summary": "The excerpt reviews how Cyberpunk 2077’s futuristi...",
#       "text": "The specific technologies presented in Cyberpunk 2...",
#       "nodes": [
#         {
#           "title": "Data collection",
#           "node_id": "0007",
#           "start_index": 7,
#           "end_index": 8,
#           "summary": "The document surveys how Cyberpunk 2077’s speculat...",
#           "text": "The specific technologies presented in Cyberpunk 2..."
#         },
#         {
#           "title": "Thematic analysis",
#           "node_id": "0008",
#           "start_index": 8,
#           "end_index": 8,
#           "summary": "The excerpt outlines a research methodology for an...",
#           "text": "envisioned and incorporated into the game. They pr..."
#         },
#         {
#           "title": "Comparison with current technologies",
#           "node_id": "0009",
#           "start_index": 8,
#           "end_index": 8,
#           "summary": "The excerpt outlines a research methodology for an...",
#           "text": "envisioned and incorporated into the game. They pr..."
#         }
#       ]
#     },
#     {
#       "title": "Themes and technologies",
#       "node_id": "0010",
#       "start_index": 8,
#       "end_index": 9,
#       "summary": "The excerpt outlines a research study that analyze...",
#       "text": "envisioned and incorporated into the game. They pr...",
#       "nodes": [
#         {
#           "title": "Overarching themes",
#           "node_id": "0011",
#           "start_index": 9,
#           "end_index": 9,
#           "summary": "The partial document analyzes Cyberpunk 2077’s vis...",
#           "text": "visionary future. Table 1, shows insights into the..."
#         },
#         {
#           "title": "Human augmentation and cybernetic enhancements",
#           "node_id": "0012",
#           "start_index": 9,
#           "end_index": 11,
#           "summary": "The excerpt analyzes how the video game *Cyberpunk...",
#           "text": "visionary future. Table 1, shows insights into the..."
#         },
#         {
#           "title": "Brain–computer interfaces and simulated reality",
#           "node_id": "0013",
#           "start_index": 11,
#           "end_index": 12,
#           "summary": "The excerpt surveys the technological and societal...",
#           "text": "Genetic Modifications  in Cyberpunk 2077 entail th..."
#         },
#         {
#           "title": "Digital representation and information access",
#           "node_id": "0014",
#           "start_index": 12,
#           "end_index": 13,
#           "summary": "The partial document surveys emerging immersive an...",
#           "text": "between the virtual and physical worlds. Haptics a..."
#         },
#         {
#           "title": "Smart environments and personalization",
#           "node_id": "0015",
#           "start_index": 13,
#           "end_index": 14,
#           "summary": "The partial document surveys how the cyberpunk set...",
#           "text": "Digital representation of the world as depicted in..."
#         },
#         {
#           "title": "Autonomous vehicles and transportation",
#           "node_id": "0016",
#           "start_index": 14,
#           "end_index": 15,
#           "summary": "The partial document surveys how Cyberpunk 2077’s ...",
#           "text": "Personalized smart environments in Cyberpunk 2077,..."
#         },
#         {
#           "title": "Advanced artificial intelligence and smart assista...",
#           "node_id": "0017",
#           "start_index": 15,
#           "end_index": 19,
#           "summary": "The excerpt presents a multidisciplinary analysis ...",
#           "text": "Improvements of self-driving models to handle out-..."
#         }
#       ]
#     },
#     {
#       "title": "Discussion",
#       "node_id": "0018",
#       "start_index": 19,
#       "end_index": 19,
#       "summary": "The excerpt discusses how Cyberpunk 2077 serves as...",
#       "text": "deeply integrated into its storytelling and gamepl..."
#     },
#     {
#       "title": "Conclusion",
#       "node_id": "0019",
#       "start_index": 19,
#       "end_index": 19,
#       "summary": "The excerpt discusses how Cyberpunk 2077 serves as...",
#       "text": "deeply integrated into its storytelling and gamepl..."
#     },
#     {
#       "title": "CRediT authorship contribution statement",
#       "node_id": "0020",
#       "start_index": 19,
#       "end_index": 19,
#       "summary": "The excerpt discusses how Cyberpunk 2077 serves as...",
#       "text": "deeply integrated into its storytelling and gamepl..."
#     },
#     {
#       "title": "Declaration of Generative AI and AI-assisted techn...",
#       "node_id": "0021",
#       "start_index": 19,
#       "end_index": 19,
#       "summary": "The excerpt discusses how Cyberpunk 2077 serves as...",
#       "text": "deeply integrated into its storytelling and gamepl..."
#     }
#   ]
# }

# %% [markdown]
# ## Step 2: Reasoning-Based Retrieval with Tree Search

# %% [markdown]
# #### 2.1 Use LLM for tree search and identify nodes that might contain relevant context

# %%
# query = "What is about simulated reality in this game?"
query = "What model was used in preparing this article and why?"

search_prompt = f"""
You are given a question and a tree structure of a document.
Each node contains a node id, node title, and a corresponding summary.
Your task is to find all nodes that are likely to contain the answer to the question.

Question: {query}

Document tree structure:
{json.dumps(tree_without_text, indent=2)}

Please reply in the following JSON format:
{{
    "thinking": "<Your thinking process on which nodes are relevant to the question>",
    "node_list": ["node_id_1", "node_id_2", ..., "node_id_n"]
}}
Directly return the final JSON structure. Do not output anything else.
"""

# %%
tree_search_result = await llm_acompletion(model="openai/gpt-oss:20b", prompt=search_prompt)

# %% [markdown]
# #### 2.2 Print retrieved nodes and reasoning process

# %%
print(tree_search_result)
# Out:
# {
#     "thinking": "The question asks which model was used to prepare the article and why. The summaries of nodes 0018, 0019, 0020, and 0021 all explicitly mention that the authors used GPT‑4 for drafting and formatting the article. No other node contains this information. Therefore, these four nodes are the relevant ones.",
#     "node_list": ["0018", "0019", "0020", "0021"]
# }

# %%
tree_search_result_json = json.loads(tree_search_result)
# tree_search_result_json

# %%
node_map = utils.create_node_mapping(tree_with_text)
# pprint(node_map)

# %%
print('\nRetrieved Nodes:')
for node_id in tree_search_result_json["node_list"]:
    node = node_map[node_id]
    print(f"Node ID: {node['node_id']}")
# Out:
# Retrieved Nodes:
# Node ID: 0018
# Node ID: 0019
# Node ID: 0020
# Node ID: 0021

# %% [markdown]
# ## Step 3: Answer Generation

# %% [markdown]
# #### 3.1 Extract relevant context from retrieved nodes

# %%
node_list = json.loads(tree_search_result)["node_list"]
relevant_content = "\n\n".join(node_map[node_id]["text"] for node_id in node_list)

print('Retrieved Context:\n')
utils.print_wrapped(relevant_content[:1000] + '...')
# Out:
# Retrieved Context:
#
# deeply integrated into its storytelling and gameplay mechanics. Balancing the benefits
# of customization and individualized solutions with concerns about surveillance, manipulation, and
# loss of autonomy will be an ongoing challenge  [140]. Our future ability to develop
# advanced biometric authentication with standardized protocols will impact our trust in the
# technology.
# Cyberpunk 2077 challenges the notion of Technological Determinism by presenting a fragmented
# future where technological adoption is uneven and often detrimental, reflecting Critical Future
# Studies emphasis on the ethical and power dynamics inherent in technological progress  [28], [74].
# The games portrayal of uneven technological uptake critiques the idea that technology inherently
# leads to societal improvement, underscoring the need for a more nuanced understanding of how
# innovations impact different communities. The diverse city districts shown in the game, each one
# presenting a very marked own cultural ident...

# %% [markdown]
# #### 3.2 Generate answer based on retrieved context

# %%
answer_prompt = f"""
Answer the question based on the context:

Question: {query}
Context: {relevant_content}

Provide a clear, concise answer based only on the context provided.
"""

answer_prompt_ext = f"""
Answer the question based on the context:

Question: {query}
Context: {relevant_content}

Provide a detailed answer based only on the context provided.
"""

print('Generated Answer:\n')
answer = await llm_acompletion(model="openai/gpt-oss:20b", prompt=answer_prompt_ext)
utils.print_wrapped(answer)
# Out:
# Generated Answer:
#
# **Model used:**
# The authors explicitly state that they employed **OpenAI’s GPT‑4** during the preparation of the
# manuscript.
#
# **Reason for using GPT‑4:**
# - **Readability enhancement:** GPT‑4 was used to polish the prose, making the article clearer and
# more accessible to readers.
# - **Technical formatting assistance:** The model helped generate correct LaTeX code for references,
# tables, and subsections, ensuring that the document complied with the required formatting standards.
# - **Efficiency in drafting:** By automating routine writing tasks, GPT‑4 allowed the authors to
# focus on higher‑level analysis and synthesis, while still reviewing and editing the content to
# maintain full responsibility for the final text.
